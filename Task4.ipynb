# %%
#CREATE A TEXT GENERATION MODEL USING GPT OR LSTM TO GENERATE COHERENT PARAGRAPHS ON SPECIFIC TOPICS.
#DELIVERABLE: A NOTEBOOK DEMONSTRATING GENERATED TEXT BASED ON USER PROMPTS.

#Text generation is a technique that involves the creation of human-like text using artificial intelligence 
#  and machine learning algorithms. It enables computers to generate coherent and contextually relevant text 
#  based on patterns and structures learned from existing textual data.

#Text generation is a fascinating application of deep learning in natural language processing (NLP). 
#  It involves training a model on a given text dataset, which can then generate new, coherent sequences 
#  of text based on the patterns it has learned.

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Define the Sample text that will be used to train the model 

input_text ="""In a survey of nearly 75,000 adults, researchers compared the participants' preferred sleep timing, known as chronotype, with their actual sleep behavior. They determined that regardless of one's preferred bedtime, everyone benefits from turning in early. Morning larks and night owls alike tended to have higher rates of mental and behavioral disorders if they stayed up late," the researchers from Stanford Medicine have said."""

# %%
# To train the model, the input text needs to be converted into a numerical format. 
# This is done using Keras’s Tokenizer, which converts the words in the text to sequences of integers. 
# Each unique word is assigned a specific index, and the tokenizer creates a mapping of words to indices.

# Tokenize the text
tokenizer = Tokenizer()

#fit_on_texts(): Creates the word-to-index mapping
tokenizer.fit_on_texts([input_text])

#Stores the number of unique words in the given input text (plus one for padding).
total_words = len(tokenizer.word_index) + 1

# %%
#fit_on_texts used in conjunction with texts_to_sequences produces the one-hot encoding for a text
# Create sequences for text generation
# For example 'Morning Larks and night' will generate the below sequences
#"Morning Larks"
#"Morning Larks and"
#"Morning Larks and night"

input_sequences = []
for line in input_text.split('.'):
   token_list = tokenizer.texts_to_sequences([line])[0]
   for i in range(1, len(token_list)):
       n_gram_sequence = token_list[:i+1]
       input_sequences.append(n_gram_sequence)

# %%
input_sequences
# Out:
# [[2, 11],
#  [2, 11, 12],
#  [2, 11, 12, 1],
#  [2, 11, 12, 1, 13],
#  [2, 11, 12, 1, 13, 14],
#  [2, 11, 12, 1, 13, 14, 15],
#  [2, 11, 12, 1, 13, 14, 15, 16],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21, 22],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21, 22, 23],
#  [2, 11, 12, 1, 13, 14, 15, 16, 3, 17, 4, 18, 5, 6, 19, 20, 21, 22, 23, 24],
#  [2,
#   11,
#   12,
#   1,
#   13,
#   14,
#   15,
#   16,
#   3,
#   17,
#   4,
#   18,
#   5,
#   6,
#   19,
#   20,
#   21,
#   22,
#   23,
#   24,
#   25],
#  [2,
#   11,
#   12,
#   1,
#   13,
#   14,
#   15,
#   16,
#   3,
#   17,
#   4,
#   18,
#   5,
#   6,
#   19,
#   20,
#   21,
#   22,
#   23,
#   24,
#   25,
#   6],
#  [2,
#   11,
#   12,
#   1,
#   13,
#   14,
#   15,
#   16,
#   3,
#   17,
#   4,
#   18,
#   5,
#   6,
#   19,
#   20,
#   21,
#   22,
#   23,
#   24,
#   25,
#   6,
#   26],
#  [7, 27],
#  [7, 27, 28],
#  [7, 27, 28, 29],
#  [7, 27, 28, 29, 1],
#  [7, 27, 28, 29, 1, 30],
#  [7, 27, 28, 29, 1, 30, 5],
#  [7, 27, 28, 29, 1, 30, 5, 31],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8, 34],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8, 34, 2],
#  [7, 27, 28, 29, 1, 30, 5, 31, 32, 33, 8, 34, 2, 35],
#  [36, 37],
#  [36, 37, 9],
#  [36, 37, 9, 38],
#  [36, 37, 9, 38, 39],
#  [36, 37, 9, 38, 39, 40],
#  [36, 37, 9, 38, 39, 40, 41],
#  [36, 37, 9, 38, 39, 40, 41, 42],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48, 7],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48, 7, 49],
#  [36, 37, 9, 38, 39, 40, 41, 42, 10, 43, 44, 1, 45, 9, 46, 47, 48, 7, 49, 50],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52,
#   53],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52,
#   53,
#   10],
#  [36,
#   37,
#   9,
#   38,
#   39,
#   40,
#   41,
#   42,
#   10,
#   43,
#   44,
#   1,
#   45,
#   9,
#   46,
#   47,
#   48,
#   7,
#   49,
#   50,
#   51,
#   4,
#   3,
#   8,
#   52,
#   53,
#   10,
#   54]]

# %%
# The above command split each sentence into sequences of increasing length, creating the n-gram sequences necessary for training.
# The sequences generated in the previous step are of varying lengths. Since the model requires all input sequences 
# to be of the same length, we pad them to a uniform size using pad_sequences(). 
# The padding is done at the beginning of the sequences to ensure that the sequences are aligned properly.
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# %%
# input sequences are now padded with zeros
input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0,  2, 11],
#        [ 0,  0,  0, ...,  2, 11, 12],
#        [ 0,  0,  0, ..., 11, 12,  1],
#        ...,
#        [ 0,  0, 36, ...,  8, 52, 53],
#        [ 0, 36, 37, ..., 52, 53, 10],
#        [36, 37,  9, ..., 53, 10, 54]])

# %%
# Preparing the input and output for the model 
# Each sequence is split into input (X) and output (y). 
# The input consists of all words in the sequence except the last one
# the output is the last word in the sequence. 
# The output (y) is one-hot encoded to allow the model to predict the next word from a vocabulary of all possible words.
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
# Build LSTM model for text generation
# Embedding Layer - Converts the input word indices into dense vectors of fixed size.
# LSTM Layer - Processes the input sequences and learns the temporal relationships between words.
# Dense Layer - Outputs a probability distribution over the vocabulary using a softmax activation function, which predicts the next word in the sequence.

model_textgen_lstm = Sequential()
model_textgen_lstm.add(Embedding(total_words, 64, input_length=max_sequence_len-1))
model_textgen_lstm.add(LSTM(100))
model_textgen_lstm.add(Dense(total_words, activation='softmax'))
# Out:
# C:\Users\mouly\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Compile the model using the Adam optimizer and categorical crossentropy as the loss function. 
model_textgen_lstm.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model for 100 epochs.
model_textgen_lstm.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.0000e+00 - loss: 4.0086
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.0743 - loss: 4.0015
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1381 - loss: 3.9953
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0850 - loss: 3.9880
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0954 - loss: 3.9786
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.0954 - loss: 3.9666
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.0850 - loss: 3.9508
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0638 - loss: 3.9183
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.0638 - loss: 3.8943
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0427 - loss: 3.8635
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0427 - loss: 3.8252
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.0954 - loss: 3.7874
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1065 - loss: 3.7639
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1062 - loss: 3.7019
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0749 - loss: 3.6784
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1274 - loss: 3.6179
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1065 - loss: 3.5804
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1169 - loss: 3.5329
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1169 - loss: 3.4626
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0958 - loss: 3.4285
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1069 - loss: 3.4113
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1697 - loss: 3.3515
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1176 - loss: 3.3015
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1388 - loss: 3.2148
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1808 - loss: 3.1683
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1284 - loss: 3.1326
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1912 - loss: 3.0277
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.1912 - loss: 2.9732
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1596 - loss: 2.9216
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1492 - loss: 2.8710
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.1704 - loss: 2.8320
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2019 - loss: 2.7716
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2023 - loss: 2.6927
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1707 - loss: 2.6659
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.2440 - loss: 2.5925
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2658 - loss: 2.5283
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2557 - loss: 2.5150
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3088 - loss: 2.4325
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3397 - loss: 2.3794
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3505 - loss: 2.3197
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3407 - loss: 2.3005
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3831 - loss: 2.2463
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4365 - loss: 2.2016
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4573 - loss: 2.1543
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4795 - loss: 2.1222
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5531 - loss: 2.0639
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5319 - loss: 2.0383
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5954 - loss: 1.9859
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5642 - loss: 1.9486
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5954 - loss: 1.8930
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5541 - loss: 1.8701
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7332 - loss: 1.8265
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6179 - loss: 1.8310
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7335 - loss: 1.7568
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7339 - loss: 1.7636
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7446 - loss: 1.7253
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7335 - loss: 1.6551
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7554 - loss: 1.6449
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7759 - loss: 1.6085
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8088 - loss: 1.5917
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7981 - loss: 1.5607
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8612 - loss: 1.5319
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7769 - loss: 1.5313
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8404 - loss: 1.4714
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8511 - loss: 1.4541
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8078 - loss: 1.4280
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8189 - loss: 1.4348
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8827 - loss: 1.4033
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8401 - loss: 1.3823
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8612 - loss: 1.3366
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9150 - loss: 1.3280
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9251 - loss: 1.3159
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9153 - loss: 1.2912
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9254 - loss: 1.2521
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9681 - loss: 1.2632
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9681 - loss: 1.2246
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9892 - loss: 1.2055
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9573 - loss: 1.1851
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9785 - loss: 1.1741
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9466 - loss: 1.1543
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9788 - loss: 1.1366
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9788 - loss: 1.1459
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9892 - loss: 1.0858
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9577 - loss: 1.1060
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9892 - loss: 1.0778
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9892 - loss: 1.0904
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9788 - loss: 1.0531
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9785 - loss: 1.0330
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9892 - loss: 1.0193
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9788 - loss: 1.0208
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9785 - loss: 1.0069
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9892 - loss: 0.9853
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9788 - loss: 0.9943
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.9572
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.9372
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.9349
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.8900
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.9009
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9892 - loss: 0.9009
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9892 - loss: 0.8747

# %%
# A trained model can be used to generate new text. 
# The function generate_text() takes a seed text and generates a specified number of new words by predicting
#   the next word repeatedly, updating the seed text with the new predictions.
def generate_text(seed_text, next_words, max_sequence_len):
   for _ in range(next_words):
       token_list = tokenizer.texts_to_sequences([seed_text])[0]
       token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
       predicted = np.argmax(model_textgen_lstm.predict(token_list), axis=-1)
       output_word = ""
       for word, index in tokenizer.word_index.items():
           if index == predicted:
               output_word = word
               break
       seed_text += " " + output_word
   return seed_text

# %%
# Test your LSTM model. Pass a seed text and see how the model generate the text
print(generate_text("Morning larks", 20, max_sequence_len))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Morning larks and night owls alike tended to have higher rates of mental and behavioral disorders if they stayed up late the
